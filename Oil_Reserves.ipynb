# %%
import numpy as np
import pandas as pd

# %%
oil_reserve = pd.read_csv('oil_reserves.csv')
oil_reserve.head()
# Out:
#                Region Country/ Region     2010     2011     2012     2013  \
# 0       North America              US   34.990   39.775   44.180   48.463
# 1       North America          Canada  174.848  174.177  173.716  173.038
# 2       North America          Mexico   11.691   11.394   11.424   11.079
# 3  S. & Cent. America       Argentina    2.524    2.525    2.354    2.330
# 4  S. & Cent. America          Brazil   14.246   15.050   15.314   15.593
#
#       2014     2015     2016
# 0   54.962   47.987   47.987
# 1  172.156  171.512  171.512
# 2   10.816    7.977    7.977
# 3    2.380    2.395    2.395
# 4   16.184   13.000   12.634

# %%
oil_reserve.interpolate(method = 'linear', limit_direction = 'forward', inplace = True)
oil_reserve
# Out:
#                 Region              Country/ Region     2010     2011  \
# 0        North America                           US   34.990   39.775
# 1        North America                       Canada  174.848  174.177
# 2        North America                       Mexico   11.691   11.394
# 3   S. & Cent. America                    Argentina    2.524    2.525
# 4   S. & Cent. America                       Brazil   14.246   15.050
# 5   S. & Cent. America                     Colombia    1.900    1.988
# 6   S. & Cent. America                      Ecuador    6.158    7.210
# 7   S. & Cent. America                         Peru    1.240    1.206
# 8   S. & Cent. America            Trinidad & Tobago    0.830    0.830
# 9   S. & Cent. America                    Venezuela  296.501  297.571
# 10  S. & Cent. America     Other S. & Cent. America    0.768    0.507
# 11    Europe & Eurasia                   Azerbaijan    7.000    7.000
# ...

# %%
oilR = oil_reserve.copy()
oilR.sort_values(['2014', '2015', '2016'], ascending = False, inplace = True)
oilR.head(1)[['Region', 'Country/ Region']]
# Out:
#                Region Country/ Region
# 9  S. & Cent. America       Venezuela

# %%
oil_R = oil_reserve.copy()
oil_R.loc[oil_R.groupby(['Region'])['2010'].idxmax()]
# Out:
#                 Region     Country/ Region     2010     2011     2012  \
# 39              Africa               Libya   47.097   48.014   48.472
# 47        Asia Pacific               China   23.236   23.749   24.409
# 17    Europe & Eurasia  Russian Federation  105.800  105.709  105.492
# 27         Middle East        Saudi Arabia  264.516  265.405  265.850
# 1        North America              Canada  174.848  174.177  173.716
# 9   S. & Cent. America           Venezuela  296.501  297.571  297.735
#
#        2013     2014     2015     2016
# 39   48.363   48.363   48.363   48.363
# 47   24.702   25.142   25.655   25.655
# 17  105.016  103.164  102.375  109.500
# 27  265.850  267.000  266.578  266.455
# 1   173.038  172.156  171.512  171.512
# 9   298.350  299.953  300.878  300.978

# %%
oil_reserve.iloc[48:49]
oil_reserve.iloc[48:49, 2:9]
# Out:
#      2010   2011  2012   2013   2014   2015   2016
# 48  5.833  5.704  5.72  5.711  5.743  4.786  4.677

# %%
#Bar Chart Representation
import matplotlib.pyplot as plt

years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016']
#reserves = [oil_reserve.iloc[48:49, 2:9]]
reserves = ['5.833', '5.704', '5.72', '5.711', '5.743', '4.786', '4.677']
explode = (0, 0, 0, 0.1, 0, 0, 0)
plt.pie(reserves, explode=explode, labels=years, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('Oil Reserves in India')
plt.show()
